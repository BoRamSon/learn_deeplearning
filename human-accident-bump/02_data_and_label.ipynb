# %% [markdown]
# ## 🟢 1. 데이터 불어오기
# - 이미지 = 싱글 이미지
# - 라벨 = 제이슨

# %% [markdown]
# <br>
#
# ### 🟡 1-1. json 파일 읽어오기

# %% [markdown]
# #### ⚫ 1. 원천데이터 경로 (1개 데이터)
# D:\078.스마트 제조 시설 안전 감시를 위한 데이터\3.개방데이터\1.데이터\Validation\01.원천데이터\VS\human-accident\bump\rgb\human-accident_bump_rgb_0001_cctv1
#
# human-accident_bump_rgb_0001_cctv1_01.png
#
#
# #### ⚫ 2. 라벨링데이터 경로 (1개 데이터)
# D:\078.스마트 제조 시설 안전 감시를 위한 데이터\3.개방데이터\1.데이터\Validation\02.라벨링데이터\VL\human-accident\bump\rgb\human-accident_bump_rgb_0001_cctv1
#
# human-accident_bump_rgb_0001_cctv1_01.json

# %%
# https://devpouch.tistory.com/33

import json
from dotenv import load_dotenv
import os

# load .env
load_dotenv()

mac_path = os.environ.get("macbook_path")
# windows_path = "C:\\Users\\bb\\Desktop\\learn_deeplearning\\human-accident-bump\\data\\human-accident_bump_rgb_0001_cctv1_01.json"    # 절대경로
windows_path = "./data/human-accident_bump_rgb_0001_cctv1_01.json"      # 상대경로


try:
    with open(windows_path, "r", encoding="utf-8-sig") as f:
        json_data = json.load(f)
except:
    with open(mac_path, "r", encoding="utf-8-sig") as f:
        json_data = json.load(f)

print(json.dumps(json_data))
# Out:
# {"meta_information": {"category": "human-accident", "event": "bump", "mode": "rgb", "shoot_time": "day", "weather": "inside", "environment": "indoor", "camera_id": "cctv1", "resolution": "fhd", "width": 1920, "height": 1080, "file_name": "human-accident_bump_rgb_0001_cctv1_01.png"}, "object_information_human": {"type_of_object": "human", "id": "h0003", "gender": "male", "tall": 168, "age": 30, "clothes": "top-work-clothes, bottom-work-clothes", "accessories": "cellphone, safety-helmet, safety-vest"}, "object_information_facility": {"type_of_object": "facility", "id": "m0002", "facility_name": "movable-stand"}, "annotations": [{"id": "h0003", "segmentation": [582.3, 296.3, 591.07, 295.45, 598.57, 303.98, 603.74, 315.09, 607.1, 332.67, 607.61, 344.55, 604.77, 352.56, 606.84, 359.28, 606.06, 368.33, 612.78, 372.46, 618.21, 381.5, 627.77, 386.41, 645.6, 393.39, 659.29, 400.63, 672.47, 402.44, 684.88, 408.38, 690.1, 413.9, 691.3, 423.6, 702.8, 436.5, 703.74, 451.53, 706.07, 466.52, 709.68, 485.64, 717.44, 507.87, 718.99, 517.17, 716.4, 526.47, 716.14, 546.63, 720.1, 546.5, 726.7, 558.2, 728.55, 566.01, 724.41, 581.77, 726.22, 589.01, 724.93, 600.12, 728.55, 604.51, 728.55, 609.42, 724.67, 618.47, 724.16, 629.58, 723.1, 638.6, 721.83, 651.54, 718.21, 654.38, 720.28, 661.1, 722.09, 672.99, 722.09, 685.14, 717.44, 700.9, 716.14, 705.55, 721.57, 712.79, 725.96, 718.21, 737.85, 730.62, 744.31, 736.04, 755.1, 737.3, 759.5, 742.7, 761.37, 751.29, 765.5, 758.78, 768.34, 764.73, 767.4, 776.3, 760.85, 783.59, 755.0, 797.9, 746.64, 805.81, 737.59, 812.01, 717.7, 814.86, 707.62, 813.56, 707.88, 830.36, 701.67, 836.05, 704.26, 852.33, 704.52, 866.28, 699.09, 877.91, 682.03, 885.66, 669.63, 882.56, 660.85, 875.07, 663.69, 841.47, 649.73, 834.75, 643.01, 817.96, 637.33, 826.49, 628.6, 838.2, 620.5, 849.5, 620.02, 856.72, 616.14, 869.38, 607.8, 878.7, 595.73, 879.46, 584.87, 876.62, 578.41, 868.61, 579.19, 859.3, 581.26, 842.76, 590.3, 830.88, 595.98, 823.9, 599.09, 818.99, 592.11, 816.92, 580.74, 806.07, 578.41, 799.09, 575.57, 791.86, 579.45, 787.98, 582.55, 777.9, 576.86, 768.08, 567.04, 756.2, 555.16, 731.91, 548.18, 715.37, 542.24, 694.44, 536.55, 663.17, 533.71, 647.41, 523.89, 622.6, 528.8, 605.55, 525.44, 597.28, 523.89, 579.96, 525.18, 563.68, 521.56, 552.31, 518.46, 538.88, 519.5, 524.41, 505.8, 510.45, 489.3, 523.1, 463.5, 526.8, 448.95, 511.74, 445.59, 494.43, 449.98, 477.37, 460.06, 459.54, 470.4, 451.28, 486.42, 435.25, 487.19, 409.93, 490.81, 395.2, 498.82, 379.18, 507.61, 370.91, 512.0, 355.15, 513.29, 345.07, 515.1, 335.25, 511.74, 326.98, 516.65, 317.94, 528.54, 305.79, 540.43, 297.26, 555.67, 288.48, 564.72, 288.22, 572.73, 291.58], "bbox": []}, {"id": "m0002", "segmentation": [], "bbox": [183.8, 0.0, 697.16, 606.7]}]}

# %% [markdown]
# #### ⚫ json에 대해서
# - json.load()
#     - json 파일을 읽어서 json object를 python dictionary로 가져옵니다.
# - json.dump()
#     - python dictionary 타입의 객체를 json 파일로 씁니다.
# - json.dumps()
#     - python dictionary 타입의 객체를 string 타입으로 가져옵니다.
#     - dictionary와 string을 출력했을 때 값이 다른 것을 확인할 수 있습니다.
# - json.loads()
#     - string 타입의 객체를 dictionary 타입으로 가져옵니다.

# %% [markdown]
# #### 오류 해결 기록
# https://musclebear.tistory.com/151

# %% [markdown]
# <br>
#
# ### 🟡 1-2. image 데이터 읽어오기
#
# https://blog.naver.com/choi_s_h/221670964510
# 파이썬의 이미지 파일 읽기와 보이기

# %%
# opencv 설치하기
# !uv add opencv-python

# %%
import matplotlib.pyplot as plt
import cv2  # image file을 처리하는 cv2 module importing

# %%
imdage_file_path = "data/human-accident_bump_rgb_0001_cctv1_01.png"

image = cv2.imread(
    imdage_file_path
)  # imread 함수를 사용하여 해당 디렉토리에 위치하고 있는 이미지 파일을 image 변수에 저장
# imread 함수로 파일을 읽어들일 때 3가지 옵션이 존재
# 1. image = cv2.imread(imdage_file_path, cv2.IMREAD_COLOR)         | cv2.IMREAD_COLOR 대신 '1'사용 가능
# 2. image = cv2.imread(imdage_file_path, cv2.IMREAD_GRAYSCALE)     | cv2.IMREAD_GRAYSCALE 대신 '0'사용 가능
# 3. image = cv2.imread(imdage_file_path, cv2.IMREAD_UNCHANGED)     | cv2.IMREAD_UNCHANGED 대신 '-1'사용 가능

# cv2.imshow('image_window', image)        # imshow("스크린 명치", 원하는 이미지) 함수를 사용하여 image라는 변수에 저장된 사진을 출력해라~
# '응답없음'으로 인해서 matplotlib를 사용하겠습니다.
plt.imshow(image)

# %% [markdown]
# <br>
#
# ### 🟡 1-3.  불러온 이미지 타입 및 변수를 출력해보기

# %%
type(image)  # 타입 = 넘파이 배열
# Out:
# numpy.ndarray

# %%
image  # 해당 image 변수 확인 시 넘파이 행렬로 구성됨을 확인
# Out:
# array([[[118, 120, 113],
#         [ 93,  95,  88],
#         [ 72,  74,  67],
#         ...,
#         [126, 131, 131],
#         [135, 140, 140],
#         [131, 136, 136]],
#
#        [[118, 120, 113],
#         [ 93,  95,  88],
#         [ 72,  74,  67],
#         ...,
#         [ 80,  85,  85],
#         [134, 139, 139],
#         [127, 132, 132]],
#
#        [[118, 120, 113],
#         [ 93,  95,  88],
#         [ 72,  74,  67],
#         ...,
#         [  0,   0,   0],
#         [ 38,  43,  41],
#         [ 99, 104, 102]],
#
#        ...,
#
#        [[ 80,  74,  69],
#         [ 66,  60,  55],
#         [ 45,  39,  34],
#         ...,
#         [ 66,  81,  79],
#         [ 37,  52,  50],
#         [  4,  19,  17]],
#
#        [[ 81,  75,  70],
#         [ 67,  61,  56],
#         [ 46,  40,  35],
#         ...,
#         [ 67,  78,  79],
#         [ 58,  69,  70],
#         [ 16,  27,  28]],
#
#        [[ 81,  75,  70],
#         [ 68,  62,  57],
#         [ 47,  41,  36],
#         ...,
#         [ 61,  72,  73],
#         [ 57,  68,  69],
#         [ 33,  44,  45]]], shape=(1080, 1920, 3), dtype=uint8)

# %% [markdown]
# <br><br>
#
# ## 🟢 2. `json 데이터 라벨 파일`에서 `어노테이션` -> `세그멘테이션` 라벨 가져오기

# %%
# json 다시 확인
# print(json_data)
print(json.dumps(json_data))
# Out:
# {"meta_information": {"category": "human-accident", "event": "bump", "mode": "rgb", "shoot_time": "day", "weather": "inside", "environment": "indoor", "camera_id": "cctv1", "resolution": "fhd", "width": 1920, "height": 1080, "file_name": "human-accident_bump_rgb_0001_cctv1_01.png"}, "object_information_human": {"type_of_object": "human", "id": "h0003", "gender": "male", "tall": 168, "age": 30, "clothes": "top-work-clothes, bottom-work-clothes", "accessories": "cellphone, safety-helmet, safety-vest"}, "object_information_facility": {"type_of_object": "facility", "id": "m0002", "facility_name": "movable-stand"}, "annotations": [{"id": "h0003", "segmentation": [582.3, 296.3, 591.07, 295.45, 598.57, 303.98, 603.74, 315.09, 607.1, 332.67, 607.61, 344.55, 604.77, 352.56, 606.84, 359.28, 606.06, 368.33, 612.78, 372.46, 618.21, 381.5, 627.77, 386.41, 645.6, 393.39, 659.29, 400.63, 672.47, 402.44, 684.88, 408.38, 690.1, 413.9, 691
# [582.3, 296.3, 591.07, 295.45, 598.57, 303.98, 603.74, 315.09, 607.1, 332.67, 607.61, 344.55, 604.77, 352.56, 606.84, 359.28, 606.06, 368.33, 612.78, 372.46, 618.21, 381.5, 627.77, 386.41, 645.6, 393.39, 659.29, 400.63, 672.47, 402.44, 684.88, 408.38, 690.1, 413.9, 691.3, 423.6, 702.8, 436.5, 703.74, 451.53, 706.07, 466.52, 709.68, 485.64, 717.44, 507.87, 718.99, 517.17, 716.4, 526.47, 716.14, 546.63, 720.1, 546.5, 726.7, 558.2, 728.55, 566.01, 724.41, 581.77, 726.22, 589.01, 724.93, 600.12, 728.55, 604.51, 728.55, 609.42, 724.67, 618.47, 724.16, 629.58, 723.1, 638.6, 721.83, 651.54, 718.21, 654.38, 720.28, 661.1, 722.09, 672.99, 722.09, 685.14, 717.44, 700.9, 716.14, 705.55, 721.57, 712.79, 725.96, 718.21, 737.85, 730.62, 744.31, 736.04, 755.1, 737.3, 759.5, 742.7, 761.37, 751.29, 765.5, 758.78, 768.34, 764.73, 767.4, 776.3, 760.85, 783.59, 755.0, 797.9, 746.64, 805.81, 737.59, 812.01, 717.7, 814.86, 707.62, 813.56, 707.88, 830.36, 701.67, 836.05, 704.26, 852.33, 704.52, 866.28, 699.09, 877.91, 682.03, 885.66, 669.63, 882.56, 660.85, 875.07, 663.69, 841.47, 649.73, 834.75, 643.01, 817.96, 637.33, 826.49, 628.6, 838.2, 620.5, 849.5, 620.02, 856.72, 616.14, 869.38, 607.8, 878.7, 595.73, 879.46, 584.87, 876.62, 578.41, 868.61, 579.19, 859.3, 581.26, 842.76, 590.3, 830.88, 595.98, 823.9, 599.09, 818.99, 592.11, 816.92, 580.74, 806.07, 578.41, 799.09, 575.57, 791.86, 579.45, 787.98, 582.55, 777.9, 576.86, 768.08, 567.04, 756.2, 555.16, 731.91, 548.18, 715.37, 542.24, 694.44, 536.55, 663.17, 533.71, 647.41, 523.89, 622.6, 528.8, 605.55, 525.44, 597.28, 523.89, 579.96, 525.18, 563.68, 521.56, 552.31, 518.46, 538.88, 519.5, 524.41, 505.8, 510.45, 489.3, 523.1, 463.5, 526.8, 448.95, 511.74, 445.59, 494.43, 449.98, 477.37, 460.06, 459.54, 470.4, 451.28, 486.42, 435.25, 487.19, 409.93, 490.81, 395.2, 498.82, 379.18, 507.61, 370.91, 512.0, 355.15, 513.29, 345.07, 515.1, 335.25, 511.74, 326.98, 516.65, 317.94, 528.54, 305.79, 540.43, 297.26, 555.67, 288.48, 564.72, 288.22, 572.73, 291.58]

# %% [markdown]
# <br><br>
#
# ## 🟢 3. 라벨에서 x, y 포인트를 가져오기

# %% [markdown]
# ### 🟡 3-1. segmentation List에서 x, y 분리하기
#
# - 0부터 시작하는
# - 짝수는 x값
# - 홀수는 y값

# %%
# segmentation

# %%
x = []
y = []

# print(len(segmentation)) # 258개 확인

for i in range(len(segmentation)):
    # 🆘 데이터가 많을 떄, for문을 사용하는 것이 적절할까?

    if i % 2 == 0:
        # x.append(i)
        x.append(segmentation[i])
    else:
        # y.append(i)
        y.append(segmentation[i])

print(f"x : {x}")
print(f"y : {y}")
# Out:
# - 선 그리기(직선, 화살표, 마커), 도형 그리기(사각형, 원, 타원, 다각형), 문자열 출력 함수를 알아보고 영상에 적용해보자!
#
# #### 하지만 다 건너뛰고 일단 **`점찍기`** 부터 해보자
# - circle이지만 이걸 점으로 생각하고 찍는다.
# - cv2.circle(img, center, radius, color, thickness=None, lineType=None, shift=None) -> img

# %%
# imread로 이미지를 가져와서 image라는 변수에 저장하였었다.
drawing_image = image.copy()  # 원본을 해치지 않기 위해 해당 이미지를 copy 해왔음.

# 🔥 먼저 하드코딩을 통해서 출력 여부만 먼저 확인을 해보겠습니다.
# cv2.circle(img, center(x,y값), radius(원의 반지름), color(R,G,B),
#               thickness=None(두께), lineType=None, shift=None) -> img
# cv2.circle(drawing_image, (580, 600), 200, (255, 0, 0), 30)
cv2.circle(drawing_image, (580, 600), 8, (255, 0, 0), -1)
cv2.circle(drawing_image, (550, 600), 8, (255, 0, 0), -1)
cv2.circle(drawing_image, (530, 600), 8, (255, 0, 0), -1)

# cv2.imshow("image_window", drawing_image)  # 응답없음으로 인해 matplotlib 사용함.
plt.imshow(drawing_image)  # 잘 그려지는 것을 확인했습니다.

# %% [markdown]
# <br>
#
# ### 🟡 4-2. 본격적으로 segmentation 값을 가지고 점 찍어보기

# %%
# imread로 이미지를 가져와서 image라는 변수에 저장하였었다.
segmentation_image = image.copy()  # 원본을 copy 해옴.

# cv2.circle(img, center(x,y값), radius(원의 반지름), color(R,G,B),
#               thickness=None(두께), lineType=None, shift=None) -> img
for i in range(len(x)):
    # 🔥float이면 overload 에러 발생
    # > Overload resolution failed:
    # >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
    # >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
    # = 공식 documents를 보면 int로만 받는 것으로 되어있기 때문에 int로 바꿔주는 것이 맞습니다.
    cv2.circle(segmentation_image, (int(x[i]), int(y[i])), 8, (255, 0, 0), -1)

plt.imshow(segmentation_image)

# %% [markdown]
# <br><br>
#
# ## 🟢 5. 사각형 영역 만들기

# %% [markdown]
# <br>
#
# ### 🟡 5-1. OpenCV - rectangle() 그려보기
#
# - cv2.rectangle(img, pt1, pt2, color, thickness=None, lineType=None, shift=None) -> img
# - cv2.rectangle(img, rec, color, thickness=None, lineType=None, shift=None) -> img
#     - img : 그림을 그릴 영상
#     - pt1, pt2 : 사각형의 두 꼭지점 좌표. (x, y) 튜플
#     - rec : 사각형 위치 정보. (x, y, w, h) 튜플
#     - color : 선 색상 또는 밝기. (B, G, R) 튜플 또는 정수값
#     - thickness : 선 두께. 기본값은 1. 음수(-1)를 지정하면 내부를 채움.
#     - shift : 그리기 좌표 값의 축소 비율. 기본값은 0

# %%
rectangle_image = segmentation_image.copy()
# segmentation이 완료된 이미지를 복사해온다.

x_min = min(x)
# print(f"x_min : {x_min}")
x_max = max(x)
# print(f"x_max : {x_max}")
y_min = min(y)
# print(f"y_min : {y_min}")
y_max = max(y)
# print(f"xy_max : {y_max}")


pt1 = (int(x_min), int(y_max))
pt2 = (int(x_max), int(y_min))
cv2.rectangle(rectangle_image, pt1, pt2, (255, 0, 0), 5)

plt.imshow(rectangle_image)
